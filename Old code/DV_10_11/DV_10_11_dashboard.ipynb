# %%
pip install dash
# Out:
# Requirement already satisfied: dash in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (3.0.4)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (6.1.2)
# Requirement already satisfied: importlib-metadata in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (72.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: colorama in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from click>=8.1.3->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from plotly>=5.0.0->dash) (1.31.0)
# Requirement already satisfied: packaging in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from requests->dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from requests->dash) (2025.4.26)
# Requirement already satisfied: six>=1.7.0 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from retrying->dash) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash-leaflet
# Out:
# Requirement already satisfied: dash-leaflet in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (1.1.3)
# Requirement already satisfied: dash>=3.0.0 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash-leaflet) (3.0.4)
# Requirement already satisfied: dash-extensions>=2.0.0 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash-leaflet) (2.0.4)
# Requirement already satisfied: dash_svg in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash-leaflet) (0.0.12)
# Requirement already satisfied: protobuf>=6.30.2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash-leaflet) (6.31.1)
# Requirement already satisfied: geobuf>=2.0.0 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash-leaflet) (2.0.0)
# Requirement already satisfied: pyyaml in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash-leaflet) (6.0.2)
# Requirement already satisfied: colorcet in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash-leaflet) (3.1.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash>=3.0.0->dash-leaflet) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash>=3.0.0->dash-leaflet) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash>=3.0.0->dash-leaflet) (6.1.2)
# Requirement already satisfied: importlib-metadata in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash>=3.0.0->dash-leaflet) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash>=3.0.0->dash-leaflet) (4.12.2)
# Requirement already satisfied: requests in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash>=3.0.0->dash-leaflet) (2.32.3)
# Requirement already satisfied: retrying in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash>=3.0.0->dash-leaflet) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash>=3.0.0->dash-leaflet) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash>=3.0.0->dash-leaflet) (72.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=3.0.0->dash-leaflet) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=3.0.0->dash-leaflet) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=3.0.0->dash-leaflet) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=3.0.0->dash-leaflet) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Werkzeug<3.1->dash>=3.0.0->dash-leaflet) (3.0.2)
# Requirement already satisfied: colorama in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from click>=8.1.3->Flask<3.1,>=1.0.4->dash>=3.0.0->dash-leaflet) (0.4.6)
# Requirement already satisfied: more-itertools>=10.6.0 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash-extensions>=2.0.0->dash-leaflet) (10.7.0)
# Requirement already satisfied: jsbeautifier>=1.15.4 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash-extensions>=2.0.0->dash-leaflet) (1.15.4)
# Requirement already satisfied: Flask-Caching>=2.3.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash-extensions>=2.0.0->dash-leaflet) (2.3.1)
# Requirement already satisfied: dataclass-wizard>=0.35.0 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash-extensions>=2.0.0->dash-leaflet) (0.35.0)
# Requirement already satisfied: pydantic>=2.10.6 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash-extensions>=2.0.0->dash-leaflet) (2.11.5)
# Requirement already satisfied: cachelib>=0.9.0 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Flask-Caching>=2.3.1->dash-extensions>=2.0.0->dash-leaflet) (0.13.0)
# Requirement already satisfied: six in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from geobuf>=2.0.0->dash-leaflet) (1.17.0)
# Requirement already satisfied: editorconfig>=0.12.2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from jsbeautifier>=1.15.4->dash-extensions>=2.0.0->dash-leaflet) (0.17.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from plotly>=5.0.0->dash>=3.0.0->dash-leaflet) (1.31.0)
# Requirement already satisfied: packaging in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from plotly>=5.0.0->dash>=3.0.0->dash-leaflet) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from pydantic>=2.10.6->dash-extensions>=2.0.0->dash-leaflet) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from pydantic>=2.10.6->dash-extensions>=2.0.0->dash-leaflet) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from pydantic>=2.10.6->dash-extensions>=2.0.0->dash-leaflet) (0.4.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from importlib-metadata->dash>=3.0.0->dash-leaflet) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from requests->dash>=3.0.0->dash-leaflet) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from requests->dash>=3.0.0->dash-leaflet) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from requests->dash>=3.0.0->dash-leaflet) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from requests->dash>=3.0.0->dash-leaflet) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dash import Dash, dcc, html
from dash.dependencies import Input, Output, State
import plotly.express as px
import dash_leaflet as dl

# %%
pip install --upgrade dash jupyter-dash
# Out:
# Requirement already satisfied: dash in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (3.0.4)
# Requirement already satisfied: jupyter-dash in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (0.4.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (6.1.2)
# Requirement already satisfied: importlib-metadata in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from dash) (72.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: ipython in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from jupyter-dash) (9.1.0)
# Requirement already satisfied: ipykernel in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from jupyter-dash) (6.29.5)
# Requirement already satisfied: ansi2html in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from jupyter-dash) (1.9.2)
# Requirement already satisfied: colorama in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from click>=8.1.3->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from plotly>=5.0.0->dash) (1.31.0)
# Requirement already satisfied: packaging in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipykernel->jupyter-dash) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipykernel->jupyter-dash) (1.8.14)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipykernel->jupyter-dash) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipykernel->jupyter-dash) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipykernel->jupyter-dash) (0.1.6)
# Requirement already satisfied: psutil in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipykernel->jupyter-dash) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipykernel->jupyter-dash) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipykernel->jupyter-dash) (6.5)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipykernel->jupyter-dash) (5.14.3)
# Requirement already satisfied: decorator in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipython->jupyter-dash) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipython->jupyter-dash) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipython->jupyter-dash) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipython->jupyter-dash) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (307)
# Requirement already satisfied: six>=1.5 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->jupyter-dash) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from requests->dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from requests->dash) (2025.4.26)
# Requirement already satisfied: executing in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from stack_data->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from stack_data->ipython->jupyter-dash) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\utente\anaconda3\envs\se4g_project\lib\site-packages (from stack_data->ipython->jupyter-dash) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Function definition (to be removed, just 1 in the code)

# %%
import requests
import pandas as pd
import geopandas as gpd
from shapely import wkt
import ipywidgets as widgets
import matplotlib.pyplot as plt
import folium
from shapely.geometry import mapping
#import leafmap as leafmap
from shapely.geometry import shape

def read_response(t):
    try:
        data = t.json() #This will convert the response to a json object
        return data
    except requests.exceptions.JSONDecodeError:
        print("Risposta non valida JSON!")
        print("Contenuto della risposta:", t.text)
        data = None 

def get_measurement_unit(pollutant):
    t=requests.post(url="http://127.0.0.1:5000/api/units", json={"var_pollutant": pollutant}) #json= data will convert the dictionary to a json object and send it to the server
    data = read_response(t) 
    return data[0]

# %% [markdown]
# # Dashboard

# %% [markdown]
# Populate the dropdown

# %%
# Function for both DV 10 and DV 11
def pollutant_dropdown():
    t=requests.get(url="http://127.0.0.1:5000/api/pollutant")
    list_pollutant = read_response(t)
    list = [{'label': pollutant, 'value': pollutant} for pollutant in list_pollutant]
    return list

# %% [markdown]
# This first part is just for the layout of the elements

# %%
# Get pollutants
#t = requests.get(url="http://127.0.0.1:5000/api/pollutant")
#list_pollutant = read_response(t)

# Get data for initial pollutant (DV 10)
def get_data_10(pollutant):
    data = {"var_pollutant": pollutant}
    t = requests.post(url="http://127.0.0.1:5000/api/DV_10", json=data)
    data = read_response(t)
    # to visualize the response, we can conver the data to a pandas geodataframe
    gdf = gpd.GeoDataFrame(data)
    gdf['geometry'] = gdf['geometry'].apply(wkt.loads)
    gdf.set_geometry('geometry', inplace=True)

    gdf = gdf.dropna(subset=['quota']) # Drop rows where 'quota' is NaN

    gdf['month'] = pd.to_datetime(gdf['month'], errors='coerce')
    gdf['month'] = gdf['month'].dt.strftime('%b %Y')
    return gdf

# Get data for initial pollutant (DV 11)
def get_data_11(pollutant):
    data = {"var_pollutant": pollutant}
    t = requests.post(url="http://127.0.0.1:5000/api/DV_11", json=data)
    data = read_response(t)
    df = pd.DataFrame(data)
    df['month'] = pd.to_datetime(df['month'], errors='coerce')
    df['month'] = df['month'].dt.strftime('%b %Y')
    return df

# %%
# contour lines file (DV 10)
import json
with open("../DATA/contour_lines.geojson", "r") as f:
    geojson_data = json.load(f)

#ADD colour to geojson based on elevation

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

def get_color(elev, min_elev=500, max_elev=3000):
    # Define a color map transitioning smoothly across elevations
    cmap = mcolors.LinearSegmentedColormap.from_list("terrain", [
        (0.0, "lawngreen"),   # Low elevation (green)
        (0.3, "yellow"),  # Mid elevation (yellow)
        (0.6, "orange"),  # High elevation (orange)
        (1.0, "brown")      # Highest elevation (red)
    ])

    # Normalize elevation to [0, 1] range
    ratio = (elev - min_elev) / (max_elev - min_elev)
    ratio = min(1, max(0, ratio))  # Clamp between 0 and 1

    # Convert colormap color to HEX format
    rgb = cmap(ratio)[:3]  # Get RGB values
    return f"#{int(rgb[0] * 255):02x}{int(rgb[1] * 255):02x}{int(rgb[2] * 255):02x}"

# Supponiamo tu abbia geojson_data come dizionario o FeatureCollection
for feature in geojson_data["features"]:
    elev = feature["properties"].get("ELEV", 1000)
    color = get_color(elev)
    feature["properties"]["color"] = color

print(geojson_data["features"][0])  # check the features structure
# Out:
# {'type': 'Feature', 'properties': {'fid': 1, 'ELEV': 2200.0, 'color': '#ec8b08'}, 'geometry': {'type': 'LineString', 'coordinates': [[10.237773054012042, 46.63439685859683], [10.237771002440088, 46.63430688921537], [10.237555801129059, 46.63427234207511], [10.237425411671927, 46.63428339632108]]}}

# %%
import dash
from dash import dcc, html, Output, Input, State
import pandas as pd
import geopandas as gpd
import requests

import plotly.express as px

import branca.colormap as cm
import dash_leaflet as dl

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from dash_extensions.javascript import assign
from dash.exceptions import PreventUpdate


# --- Dash App ---
app = dash.Dash(__name__)

#DV 10 functions --------------------------------------------------
# Style function for contour lines 

style = assign("""
function(feature) {
    return {
        color: feature.properties.color || "blue",
        weight: 1,
        opacity: 0.8
    };
}
""")

# DV 11 functions --------------------------------------------------
def get_years(df):
    return sorted(df["month"].str[-4:].unique())

def get_months(df, year):
    months = sorted(df[df["month"].str.contains(str(year[0]))]["month"].str[:3].unique(),
                    # key to get the months in order
                    key=lambda m: ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"].index(m))
    return ["All"] + months

# LAYOUT 
app.layout = html.Div([
    # DV 10
    html.Div([
        html.H3("DV 10 - Correlation map between monthly average of pollutant and station height"),
        html.Label("Pollutant:"),
        dcc.Dropdown(
            id='pollutant-dropdown_dv_10_11',
            options=pollutant_dropdown(),
            style={'margin-top': 20, 'margin-bottom': '20'},
        ),
        html.Div([
            html.Button('Visualize/update elevation map', id='el_map_dv_10', n_clicks=0, style={'margin-top': 20, 'margin-bottom': 20, 'padding': '6px 12px', 'fontSize': '15px'})
        ], style={'textAlign': 'center'}),

        # Loading wrapper for the map
        dcc.Loading(
            type="dot",  
            children=dl.Map(
                id="map",
                center=[45.64, 9.60],
                zoom=7,
                children=[dl.TileLayer(), dl.LayersControl(id="layers-control_dv_10")],
                style={"opacity": 0.7, "height": "50vh"},
            )
        )
    ]),

    html.Hr(style={"border": "1px solid lightgreen", "opacity": 0.7, "margin": "30px 0"}),  # Divider

    # DV 11
    html.Div([
        html.H3("DV 11 - Correlation between monthly average of pollutant and station height"),
        html.Label("Select between available years of the pollutant chosen in DV 10:"),
        dcc.Slider(id='year-slider', step=1.0),
        dcc.Dropdown(id='month-dropdown'),
        html.Div([
            html.Button('Visualize/update plot', id='el_plot_dv_11', n_clicks=0, style={'margin-top': 20, 'margin-bottom': 20, 'padding': '6px 12px', 'fontSize': '15px'})
        ], style={'textAlign': 'center'}),

        # Loading wrapper for the scatter plot
        dcc.Loading(
            type="dot",
            children=dcc.Graph(id='scatter-plot', style={'margin-top': '20px'})
        )
    ]),
], style={'padding': 20, 'margin': 2, 'border': '2px solid lightgreen', 'border-radius': '10px'})

# DV 10 callbacks ---------------------------------------------------------------------------
@app.callback(
    Output("layers-control_dv_10", "children"),
    Input("el_map_dv_10", "n_clicks"),
    State("pollutant-dropdown_dv_10_11", "value")    
)
def update_layers_dv_10(n_clicks, selected_pollutant):
    if n_clicks == 0:
      return []
    
    if n_clicks > 0 and not selected_pollutant:
        return [
                dl.TileLayer(),
                dl.Popup(
                    position=[45.64, 9.60],  # Central position
                    children=html.Div(
                        "Select a pollutant to visualize the map",
                        style={"backgroundColor": "red", "color": "white", "padding": "10px", "borderRadius": "5px"}
                    ))
            ]
    
    gdf = get_data_10(selected_pollutant)
    unit = get_measurement_unit(selected_pollutant)
    colormap_c = cm.LinearColormap(["blue", "lightblue", "yellow", "orange", "red"], vmin=gdf['monthly_average'].min(), vmax=gdf['monthly_average'].max())
    gdf["color"] = gdf["monthly_average"].apply(lambda x: colormap_c(x)[:7])

    return [
        dl.Overlay(
                dl.GeoJSON(
                    data=geojson_data,  # Path to the GeoJSON file
                    zoomToBounds=True,
                    options={"style":style}
                 ),
                name="Contour lines",
                checked=True
            ),

            # Overlay dinamici per ogni anno
            *[
                dl.Overlay(
                    dl.LayerGroup([
                        dl.CircleMarker(
                            center=[row.geometry.y, row.geometry.x],
                            radius=5,
                            color=row["color"],
                            fill=False,
                            fillOpacity=0.8,
                            children=[dl.Tooltip(f"{row['month']}: {row['monthly_average']} {unit}")]
                        )
                        for _, row in gdf[gdf["month"].str.contains(str(year))].iterrows()
                    ]),
                    name=f"{year}",
                    checked=(year == get_years(gdf)[-2])  # default most recent year (-1) checked
                )
                for year in get_years(gdf)
            ]
    ]



# DV 11 calbacks --------------------------------------------------------------------------
@app.callback(
    [Output('year-slider', 'min'),
     Output('year-slider', 'max'),
     Output('year-slider', 'value'),
     Output('year-slider', 'marks'),
     Output('month-dropdown', 'options'),
     Output('month-dropdown', 'value')],
    Input('pollutant-dropdown_dv_10_11', 'value')
)
def update_years_months(pollutant):
    if not pollutant:
        return (0, 0, 0, {}, [], 'not set')
    df = get_data_11(pollutant)
    years = get_years(df)
    months = get_months(df, years[0])

    return (float(years[0]), float(years[-1]), float(years[0]), {y: y for y in years},
            [{'label': m, 'value': m} for m in months], months[0]) #Default month set to ALL

@app.callback(
    Output('scatter-plot', 'figure'),
    Input("el_plot_dv_11", "n_clicks"),
    State('pollutant-dropdown_dv_10_11', 'value'), 
    State('year-slider', 'value'),
    State('month-dropdown', 'value')
)
def update_plot(n_clicks, pollutant, year, month):
    if n_clicks == 0:
      return px.scatter ()  # Return an empty figure if no button has been clicked
        
    if n_clicks > 0 and (not pollutant or not year or month is None):
        return px.scatter().update_layout(
            annotations=[dict(
                    text="Please select a pollutant, year and month to visualize the plot",
                    xref="paper", yref="paper",
                    showarrow=False,
                    font=dict(size=14, color="white"),
                    bgcolor="red",
                    borderpad=5)])
    df = get_data_11(pollutant)
    unit = get_measurement_unit(pollutant)
    df_filtered = df[df["month"].str.contains(str(year))]

    if month != "All":
        df_selected = df_filtered[df_filtered["month"].str.startswith(month)]
        df_other = df_filtered[~df_filtered["month"].str.startswith(month)]
    else:
        df_selected = df_filtered
        df_other = pd.DataFrame()
    fig = px.scatter(
        df_selected,
        x='monthly_average',
        y='quota',
        color='monthly_average',
        color_continuous_scale='RdYlBu_r',
        labels={
            'monthly_average': f"Monthly Average per pollutant {unit}",
            'quota': "Height [m]"
        },
        title=f"Correlation between monthly average of {pollutant} and station height"
    ).update_traces(marker=dict(size=8))

    fig.update_coloraxes(showscale=False)  # Remove color bar
    if not df_other.empty:
        fig.add_scatter(
            x=df_other['monthly_average'],
            y=df_other['quota'],
            mode='markers',
            marker=dict(color='grey', opacity=0.2),
            name='Other months'
        )
    fig.update_layout(showlegend=False)
    return fig



# In Jupyter, use run_server not run()
print("Starting Dashboard...")
app.run(port=8089)
# Out:
# Starting Dashboard...
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8089/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
